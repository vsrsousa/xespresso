# %%
# !echo $PYTHONPATH
# Out:
# /scratch/projects/xespresso:/home/vinicius/.local/bin:/home/vinicius/opt/EDMFTF-Jan-2019/bin:/home/vinicius/opt/triqs/lib/python2.7/site-packages::/scratch/builds/intel/symWannier/src

# %%
from xespresso.remote_manager import RemoteRunner

# %%
# Configurações do servidor
runner = RemoteRunner(
    hostname="medusa.fis.uerj.br",
    username="vinicius",
    password="AcimadeTudoRN@1981",  # ou use key_path se preferir
#    port=2222,  # ou 22 se for padrão
    remote_base_dir="/home/vinicius/xespresso_jobs",
#    module_command="module load quantum_espresso/7.4.1-intel-mkl-mpi"
    module_command="module load quantum-espresso/7.4.1-intel-mkl-mpi"
)

# %%
runner.test_connection()
# Out:
# INFO     [_log                ]: Connected (version 2.0, client OpenSSH_8.9p1)
# INFO     [_log                ]: Authentication (publickey) successful!
# ✅ Conexão SSH bem-sucedida com medusa.fis.uerj.br:22 como vinicius

# %%
runner.check_quantum_espresso()
# Out:
# INFO     [_log                ]: Connected (version 2.0, client OpenSSH_8.9p1)
# INFO     [_log                ]: Authentication (publickey) successful!
# ✅ Quantum ESPRESSO detectado: /home/shared/opt/quantum-espresso/intel-2021.4.0/7.4.1/bin/pw.x
# '/home/shared/opt/quantum-espresso/intel-2021.4.0/7.4.1/bin/pw.x'

# %%
runner.list_available_modules()
# Out:
# INFO     [_log                ]: Connected (version 2.0, client OpenSSH_8.9p1)
# INFO     [_log                ]: Authentication (publickey) successful!
# 📦 Módulos disponíveis:
#
# ------- /home/shared/spack/share/spack/modules/linux-ubuntu22.04-skylake -------
# autoconf/2.72-gcc-9.5.0-r2te5s3
# autoconf/2.72-gcc-11.4.0-ot7iit5
# automake/1.16.5-gcc-9.5.0-5bh2r6a
# automake/1.16.5-gcc-11.4.0-jjnepwf
# berkeley-db/18.1.40-gcc-9.5.0-5sbaa6c
# berkeley-db/18.1.40-gcc-11.4.0-g6p3nsc
# binutils/2.43.1-gcc-11.4.0-zqanes3
# bison/3.8.2-gcc-9.5.0-mvcbakx
# bzip2/1.0.8-gcc-9.5.0-z5ylwsq
# bzip2/1.0.8-gcc-11.4.0-7s5zjjz
# ca-certificates-mozilla/2023-05-30-gcc-9.5.0-mngnrwv
# cmake/3.30.5-gcc-9.5.0-xxiturg
# curl/8.10.1-gcc-9.5.0-47ox6xw
# diffutils/3.10-gcc-9.5.0-jaja7zu
# diffutils/3.10-gcc-11.4.0-uuy55ms
# expat/2.6.4-gcc-9.5.0-hnpqhz5
# findutils/4.9.0-gcc-9.5.0-ddmk4hl
# findutils/4.9.0-gcc-11.4.0-y5yi675
# gawk/5.3.1-gcc-11.4.0-iy7dfho
# gcc-runtime/9.5.0-gcc-9.5.0-x7hyzxp
# ...
